# %%
import numpy as np
import pandas as pd
import scipy as sp
import sklearn
from gensim.models import ldamodel
from gensim.models import Word2Vec
import gensim.corpora
from ast import literal_eval

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.decomposition import NMF
from sklearn.preprocessing import normalize
import pickle

# %%
data = pd.read_csv('./clean_jd_data.csv')

# %%
data.pseg_words = data.pseg_words.apply(literal_eval)

# %%
attrs = list(
    set([attr for ls in data.pseg_words for elem in ls for wd, attr in elem]) 
    - set(['a', 'd', 'i', 'l'])
)

# %%
data['words'] = [[wd for elem in ls for wd, attr in elem if attr in attrs and len(wd) > 1] for ls in data.pseg_words]
data_text = data[['words']]
train_headlines = [value[0] for value in data_text.values]

# %% [markdown]
# # LDA implement

# %%
num_topics = 10

# %%
id2word = gensim.corpora.Dictionary(train_headlines)
corpus = [id2word.doc2bow(text) for text in train_headlines]
lda = ldamodel.LdaModel(corpus=corpus, id2word=id2word, num_topics=num_topics)

# %%
def get_lda_topics(model, num_topics, topn):
    word_dict = {}
    for i in range(num_topics):
        words = model.show_topic(i, topn=topn)
        word_dict['Topic' + '{:02d}'.format(i+1)] = [word[0] for word in words]
    return pd.DataFrame(word_dict)

# %%
get_lda_topics(lda, num_topics, 30)
# Out:
#    Topic01 Topic02 Topic03 Topic04 Topic05 Topic06 Topic07 Topic08 Topic09  \
# 0       手机      手机      手机      没有      手机      耳机      手机      手机      值得
# 1       颜值      运行      价格      问题      快递      没有      问题      屏幕      购买
# 2       手感      速度      颜色      手机      物流      手机      知道      华为      机子
# 3     vivo      拍照      支持      失望      收到      赠品      客服      荣耀      不行
# 4       朋友      电池      苹果      想象      包装      声音      垃圾      王者      没有
# 5       照片      充电      黑色      功能      购物      买来      出现     摄像头     充电器
# 6       拿到      外观      国产      使用      速度      评论      不到      手感      手机
# 7       像素     玩游戏      开心      钢化      发货      音乐      不能      使用      推荐
# 8       入手      屏幕      白色      不会      服务      机器      售后      系统      能力
# 9       拍照      手感      蓝色      屏幕      质量      客服      信号      性能      说好
# 10      反应      内存      媳妇      影响      客服      杠杠      发现     性价比      拥有
# 11      游戏      功能      音响      应用      送货      少女      网络      起来      电池
# 12     实体店      使用      抢到      发现      下单      满足      不了      拍照      充电
# 13      外观      发热      拿到      大屏      态度     买手机      屏幕      外观      太差
# 14      不会      小时      同事      软件      小哥      处理      华为      整体      礼品
# 15      红色      电量      送到      知道      好评     消费者      情况      支持      建议
# 16      全屏      总体      同学      送给      配送      赠送      只能      全面      逆光
# 17      活动     速度快      老妈      样子      到货      怀疑      不想      游戏     拍出来
# 18      看到      系统      手感      微信      自营      追加      联系      机身      发票
# 19      无线      像素      礼物      好像    服务态度      产品      视频      希望      后悔
# 20      体验      评价    外观设计      试用      评价      保价      申请      红魔      客户
# 21      电影      耗电      透明      语音      商品      保护      显示      体验      没用
# 22      关注     性价比      拆开      自带      正品      盒子      解决     努比亚      方面
# 23      选择      颜色      不用      棒棒      体验      品质      信赖      做工    个人感觉
# 24      期待      起来      使用      估计      追评      不能      不行      三星      解释
# 25      关键      游戏      音箱      不能      时间      不值      质量      设计      心情
# 26      应该      音质      实在    待机时间      拿到      新机      死机      前置      质量
# 27      上手      物流      儿子      遇到      外观      礼盒      时间      配置      呵呵
# 28      美图      视频      后壳      预期      抢购      买完      电话      玻璃     数据线
# 29      配置      颜值      性能      情况      卖家      不到      重启      担心      原装
#
#    Topic10
# 0       指纹
# 1       解锁
# 2       魅族
# 3       手机
# 4       系统
# 5       屏幕
# 6       三星
# 7       小米
# 8       识别
# 9       体验
# 10      游戏
# 11      屏下
# 12      操作
# 13    指纹识别
# 14    人脸识别
# 15      模式
# 16      缺点
# 17      外形
# 18      希望
# 19      散热
# 20      方面
# 21      全面
# 22      优点
# 23      优化
# 24      手势
# 25      追求
# 26      拍照
# 27      不了
# 28      反应
# 29      科技

# %% [markdown]
# # NMF implement

# %%
sentences = [' '.join(text) for text in train_headlines]

# %%
# The CountVectorizer module return a matrix of size(Documents X Features), where the value of 
# a cell is going to be the number of times of the feature (word) appear in that document.
vectorizer = CountVectorizer(analyzer='word', max_features=5000)
x_counts = vectorizer.fit_transform(sentences)

# %%
# Set a TFIDF transformer, transform the counts with the model and normalize the values
transformer = TfidfTransformer(smooth_idf=False)
x_tfidf = transformer.fit_transform(x_counts)
xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

# %%
model = NMF(n_components=num_topics, init='nndsvd')
model.fit(xtfidf_norm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0,
#   max_iter=200, n_components=10, random_state=None, shuffle=False,
#   solver='cd', tol=0.0001, verbose=0)

# %%
def get_nmf_topics(model, num_topics, topn):
    feat_names = vectorizer.get_feature_names()
    word_dict = {}
    
    for i in range(num_topics):
        words_ids = model.components_[i].argsort()[:-topn-1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic ' + '{:02d}'.format(i+1)] = words
    return pd.DataFrame(word_dict)

# %%
num_topics = 5
get_nmf_topics(model, num_topics, 30)
# Out:
#    Topic 01 Topic 02 Topic 03 Topic 04 Topic 05
# 0        手机       屏幕       没有       物流       电池
# 1        收到       系统       问题       收到       充电
# 2        华为       反应       想象       包装       不行
# 3       玩游戏       起来       赠品       质量       耗电
# 4        快递      玩游戏       发票       服务      玩游戏
# 5        垃圾      分辨率       收到       购物       小时
# 6        问题       看着       客服       评价       外观
# 7        游戏       三星       钢化       客服       问题
# 8        性能       视频       发现     服务态度       能力
# 9        颜值       颜色       包装       使用       系统
# 10       苹果       使用       失望       下单       使用
# 11      性价比       运行       使用       商品       发热
# 12       拿到       操作       功能       外观       评价
# 13       三星       充电       系统       反应       方面
# 14       包装       像素       华为       正品       游戏
# 15       小米       划痕       出现       好评       太差
# 16       发热      摄像头      充电器       拿到       信号
# 17       起来       华为       评价       性能       电量
# 18       系统      性价比       苹果       态度       还好
# 19       使用       眼睛       毛病       机子       不够
# 20       反应       王者       快递       起来       像素
# 21       发烫       总体       充电      性价比       反应
# 22       客服       质量       无线       小哥      性价比
# 23       功能       性能       价格       体验       总体
# 24     oppo       游戏       体验       追评       华为
# 25       体验       音质       小米       颜色       时间
# 26       像素       方面       宣传       机器       性能
# 27       购买       电影       声音       值得       够用
# 28       值得       问题       信号      速度快       苹果
# 29       充电       出现       说好       送到       王者
